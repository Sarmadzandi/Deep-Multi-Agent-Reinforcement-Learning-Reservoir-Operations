# %% [markdown]
# # **Access to the Simulator Code**
#
# The code for this simulator **is not publicly available**. If you need access to it, please get in touch with me via email. Upon approval of your request, access to the code will be granted.
#
# Email for inquiries: sarmadzandi@gmail.com
